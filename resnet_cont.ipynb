# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score)
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.densenet import DenseNet121
from keras.applications.resnet import ResNet101
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from skimage import io
from keras.preprocessing import image

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1

# %% [markdown]
# ## Data

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content/drive/MyDrive/03_March/Btech_cv19/ConStr/'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#             File  DiseaseID Disease Type
# 0  COVID/326.png          0        COVID
# 1  COVID/351.png          0        COVID
# 2  COVID/317.png          0        COVID
# 3  COVID/357.png          0        COVID
# 4  COVID/304.png          0        COVID

# %% [markdown]
# ## Randomize the order of training set

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                  File  DiseaseID Disease Type
# 0    non-COVID/79.png          1    non-COVID
# 1  non-COVID/1035.png          1    non-COVID
# 2       COVID/548.png          0        COVID
# 3   non-COVID/309.png          1    non-COVID
# 4      COVID/1103.png          0        COVID

# %% [markdown]
# ## Plot a histogram

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %% [markdown]
# ## Display images of COVID

# %%
plot_defects('COVID', 3, 3)

# %% [markdown]
# ## Display images of non-COVID

# %%
plot_defects('non-COVID', 3, 3)

# %% [markdown]
# ## Image Read and Resize

# %%
IMAGE_SIZE = 128
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ## Data Augmnetation

# %%
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

# %% [markdown]
# ## Training Images

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2530it [06:54,  6.10it/s]
# Train Shape: (2530, 128, 128, 3)

# %% [markdown]
# ## Converting Labels to Categorical

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %% [markdown]
# ## Train Test Splitting

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %% [markdown]
# ## 128*128 training images

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 100
SIZE=128
N_ch=3

# %% [markdown]
# ## DenseNet121 Model

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# ## ResNet 101 Model

# %%
def build_resnet():
    densenet = ResNet101(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# ## Fitting Model DenseNet121 and ResNet101

# %%
# model = build_densenet()

# %%
model = build_resnet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 1s 0us/step
# 171458560/171446536 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 3)       84
#
#  resnet101 (Functional)      (None, None, None, 2048)  42658176
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 43,192,534
# Trainable params: 43,082,582
# Non-trainable params: 109,952
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=2, learning_rate =1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)


datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.85003, saving model to model.h5
# 31/31 - 44s - loss: 1.1085 - accuracy: 0.5612 - val_loss: 0.8500 - val_accuracy: 0.5158 - lr: 0.0020 - 44s/epoch - 1s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.85003 to 0.69792, saving model to model.h5
# 31/31 - 15s - loss: 0.9522 - accuracy: 0.6398 - val_loss: 0.6979 - val_accuracy: 0.4625 - lr: 0.0020 - 15s/epoch - 498ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.69792
# 31/31 - 13s - loss: 0.8340 - accuracy: 0.6883 - val_loss: 0.8463 - val_accuracy: 0.5158 - lr: 0.0020 - 13s/epoch - 414ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.69792
# 31/31 - 13s - loss: 0.7326 - accuracy: 0.7179 - val_loss: 1.6798 - val_accuracy: 0.4842 - lr: 0.0020 - 13s/epoch - 423ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.69792
# 31/31 - 13s - loss: 0.6667 - accuracy: 0.7566 - val_loss: 0.9182 - val_accuracy: 0.4842 - lr: 0.0020 - 13s/epoch - 418ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.69792
# 31/31 - 13s - loss: 0.6033 - accuracy: 0.7796 - val_loss: 0.6989 - val_accuracy: 0.5316 - lr: 0.0020 - 13s/epoch - 421ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.69792 to 0.69176, saving model to model.h5
# 31/31 - 15s - loss: 0.5316 - accuracy: 0.8092 - val_loss: 0.6918 - val_accuracy: 0.5296 - lr: 0.0020 - 15s/epoch - 497ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.69176
# 31/31 - 13s - loss: 0.4765 - accuracy: 0.8296 - val_loss: 3.1602 - val_accuracy: 0.4842 - lr: 0.0020 - 13s/epoch - 424ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.69176
# 31/31 - 14s - loss: 0.4145 - accuracy: 0.8286 - val_loss: 1.6572 - val_accuracy: 0.4842 - lr: 0.0020 - 14s/epoch - 436ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.69176
# 31/31 - 13s - loss: 0.4103 - accuracy: 0.8454 - val_loss: 2.8296 - val_accuracy: 0.4842 - lr: 0.0020 - 13s/epoch - 431ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 11: val_loss did not improve from 0.69176
# 31/31 - 13s - loss: 0.3841 - accuracy: 0.8495 - val_loss: 0.8980 - val_accuracy: 0.4289 - lr: 0.0020 - 13s/epoch - 432ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.69176
# 31/31 - 13s - loss: 0.3859 - accuracy: 0.8485 - val_loss: 1.5850 - val_accuracy: 0.5158 - lr: 0.0010 - 13s/epoch - 434ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.69176
# 31/31 - 14s - loss: 0.3305 - accuracy: 0.8633 - val_loss: 0.9649 - val_accuracy: 0.5158 - lr: 0.0010 - 14s/epoch - 441ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.69176
# 31/31 - 14s - loss: 0.3132 - accuracy: 0.8719 - val_loss: 0.6999 - val_accuracy: 0.5494 - lr: 0.0010 - 14s/epoch - 442ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.69176
# 31/31 - 14s - loss: 0.3180 - accuracy: 0.8628 - val_loss: 0.6990 - val_accuracy: 0.5909 - lr: 0.0010 - 14s/epoch - 446ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.69176 to 0.62467, saving model to model.h5
# 31/31 - 16s - loss: 0.3261 - accuracy: 0.8730 - val_loss: 0.6247 - val_accuracy: 0.6601 - lr: 0.0010 - 16s/epoch - 514ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.62467 to 0.60830, saving model to model.h5
# 31/31 - 16s - loss: 0.3024 - accuracy: 0.8765 - val_loss: 0.6083 - val_accuracy: 0.6601 - lr: 0.0010 - 16s/epoch - 517ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.60830 to 0.56728, saving model to model.h5
# 31/31 - 16s - loss: 0.3176 - accuracy: 0.8724 - val_loss: 0.5673 - val_accuracy: 0.7154 - lr: 0.0010 - 16s/epoch - 525ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2865 - accuracy: 0.8791 - val_loss: 0.5708 - val_accuracy: 0.7213 - lr: 0.0010 - 14s/epoch - 442ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2784 - accuracy: 0.8832 - val_loss: 0.5852 - val_accuracy: 0.7036 - lr: 0.0010 - 14s/epoch - 443ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2658 - accuracy: 0.8852 - val_loss: 0.6715 - val_accuracy: 0.6364 - lr: 0.0010 - 14s/epoch - 445ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2606 - accuracy: 0.8934 - val_loss: 0.7155 - val_accuracy: 0.6285 - lr: 0.0010 - 14s/epoch - 445ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2636 - accuracy: 0.8967 - val_loss: 0.7359 - val_accuracy: 0.6285 - lr: 0.0010 - 14s/epoch - 447ms/step
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 24: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2606 - accuracy: 0.8913 - val_loss: 0.7952 - val_accuracy: 0.6087 - lr: 0.0010 - 14s/epoch - 444ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2572 - accuracy: 0.8913 - val_loss: 0.7083 - val_accuracy: 0.6403 - lr: 5.0000e-04 - 14s/epoch - 442ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2507 - accuracy: 0.8949 - val_loss: 0.6176 - val_accuracy: 0.6877 - lr: 5.0000e-04 - 14s/epoch - 443ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.56728
# 31/31 - 14s - loss: 0.2338 - accuracy: 0.9005 - val_loss: 0.6018 - val_accuracy: 0.6917 - lr: 5.0000e-04 - 14s/epoch - 451ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.56728 to 0.56060, saving model to model.h5
# 31/31 - 16s - loss: 0.2318 - accuracy: 0.9031 - val_loss: 0.5606 - val_accuracy: 0.7213 - lr: 5.0000e-04 - 16s/epoch - 520ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.56060 to 0.44188, saving model to model.h5
# 31/31 - 17s - loss: 0.2273 - accuracy: 0.9051 - val_loss: 0.4419 - val_accuracy: 0.7984 - lr: 5.0000e-04 - 17s/epoch - 536ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.44188 to 0.36544, saving model to model.h5
# 31/31 - 16s - loss: 0.2276 - accuracy: 0.9015 - val_loss: 0.3654 - val_accuracy: 0.8340 - lr: 5.0000e-04 - 16s/epoch - 532ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.36544 to 0.30049, saving model to model.h5
# 31/31 - 16s - loss: 0.2187 - accuracy: 0.9092 - val_loss: 0.3005 - val_accuracy: 0.9012 - lr: 5.0000e-04 - 16s/epoch - 526ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.30049 to 0.27928, saving model to model.h5
# 31/31 - 16s - loss: 0.2255 - accuracy: 0.9071 - val_loss: 0.2793 - val_accuracy: 0.9012 - lr: 5.0000e-04 - 16s/epoch - 526ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.27928
# 31/31 - 14s - loss: 0.2333 - accuracy: 0.9046 - val_loss: 0.2898 - val_accuracy: 0.9051 - lr: 5.0000e-04 - 14s/epoch - 445ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.27928
# 31/31 - 14s - loss: 0.2125 - accuracy: 0.9107 - val_loss: 0.2883 - val_accuracy: 0.8794 - lr: 5.0000e-04 - 14s/epoch - 441ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.27928
# 31/31 - 14s - loss: 0.2236 - accuracy: 0.9087 - val_loss: 0.2992 - val_accuracy: 0.8617 - lr: 5.0000e-04 - 14s/epoch - 442ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.27928
# 31/31 - 14s - loss: 0.2347 - accuracy: 0.9010 - val_loss: 0.6203 - val_accuracy: 0.6719 - lr: 5.0000e-04 - 14s/epoch - 440ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.27928
# 31/31 - 14s - loss: 0.2000 - accuracy: 0.9194 - val_loss: 0.3678 - val_accuracy: 0.8261 - lr: 5.0000e-04 - 14s/epoch - 442ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.27928 to 0.21444, saving model to model.h5
# 31/31 - 16s - loss: 0.2253 - accuracy: 0.9087 - val_loss: 0.2144 - val_accuracy: 0.9091 - lr: 5.0000e-04 - 16s/epoch - 525ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 0.21444 to 0.16394, saving model to model.h5
# 31/31 - 16s - loss: 0.1985 - accuracy: 0.9250 - val_loss: 0.1639 - val_accuracy: 0.9348 - lr: 5.0000e-04 - 16s/epoch - 523ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.16394 to 0.16076, saving model to model.h5
# 31/31 - 16s - loss: 0.1983 - accuracy: 0.9138 - val_loss: 0.1608 - val_accuracy: 0.9407 - lr: 5.0000e-04 - 16s/epoch - 522ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.16076
# 31/31 - 14s - loss: 0.2202 - accuracy: 0.9173 - val_loss: 0.3088 - val_accuracy: 0.8953 - lr: 5.0000e-04 - 14s/epoch - 451ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.16076
# 31/31 - 14s - loss: 0.1982 - accuracy: 0.9230 - val_loss: 0.2013 - val_accuracy: 0.9249 - lr: 5.0000e-04 - 14s/epoch - 445ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.16076
# 31/31 - 14s - loss: 0.1994 - accuracy: 0.9143 - val_loss: 0.1694 - val_accuracy: 0.9289 - lr: 5.0000e-04 - 14s/epoch - 444ms/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 0.16076 to 0.15574, saving model to model.h5
# 31/31 - 16s - loss: 0.1880 - accuracy: 0.9209 - val_loss: 0.1557 - val_accuracy: 0.9387 - lr: 5.0000e-04 - 16s/epoch - 527ms/step
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 45: val_loss did not improve from 0.15574
# 31/31 - 14s - loss: 0.2051 - accuracy: 0.9189 - val_loss: 0.1939 - val_accuracy: 0.9130 - lr: 5.0000e-04 - 14s/epoch - 445ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.15574
# 31/31 - 14s - loss: 0.1870 - accuracy: 0.9270 - val_loss: 0.1697 - val_accuracy: 0.9229 - lr: 2.5000e-04 - 14s/epoch - 442ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.15574
# 31/31 - 14s - loss: 0.2008 - accuracy: 0.9173 - val_loss: 0.2537 - val_accuracy: 0.8814 - lr: 2.5000e-04 - 14s/epoch - 448ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.15574
# 31/31 - 14s - loss: 0.1761 - accuracy: 0.9276 - val_loss: 0.2740 - val_accuracy: 0.8794 - lr: 2.5000e-04 - 14s/epoch - 445ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.15574
# 31/31 - 14s - loss: 0.1702 - accuracy: 0.9337 - val_loss: 0.1567 - val_accuracy: 0.9289 - lr: 2.5000e-04 - 14s/epoch - 448ms/step
# Epoch 50/100
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 50: val_loss improved from 0.15574 to 0.14593, saving model to model.h5
# 31/31 - 16s - loss: 0.1742 - accuracy: 0.9327 - val_loss: 0.1459 - val_accuracy: 0.9407 - lr: 2.5000e-04 - 16s/epoch - 525ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.14593
# 31/31 - 14s - loss: 0.1844 - accuracy: 0.9301 - val_loss: 0.1473 - val_accuracy: 0.9368 - lr: 1.2500e-04 - 14s/epoch - 444ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.14593
# 31/31 - 14s - loss: 0.1789 - accuracy: 0.9255 - val_loss: 0.1477 - val_accuracy: 0.9407 - lr: 1.2500e-04 - 14s/epoch - 444ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.14593
# 31/31 - 14s - loss: 0.1850 - accuracy: 0.9214 - val_loss: 0.1518 - val_accuracy: 0.9348 - lr: 1.2500e-04 - 14s/epoch - 450ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.14593
# 31/31 - 14s - loss: 0.1668 - accuracy: 0.9321 - val_loss: 0.1590 - val_accuracy: 0.9269 - lr: 1.2500e-04 - 14s/epoch - 441ms/step
# Epoch 55/100
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 55: val_loss did not improve from 0.14593
# 31/31 - 14s - loss: 0.1782 - accuracy: 0.9250 - val_loss: 0.1492 - val_accuracy: 0.9328 - lr: 1.2500e-04 - 14s/epoch - 442ms/step
# Epoch 56/100
#
# Epoch 56: val_loss improved from 0.14593 to 0.14224, saving model to model.h5
# 31/31 - 17s - loss: 0.1807 - accuracy: 0.9265 - val_loss: 0.1422 - val_accuracy: 0.9387 - lr: 6.2500e-05 - 17s/epoch - 537ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1740 - accuracy: 0.9270 - val_loss: 0.1429 - val_accuracy: 0.9368 - lr: 6.2500e-05 - 14s/epoch - 448ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1705 - accuracy: 0.9306 - val_loss: 0.1536 - val_accuracy: 0.9308 - lr: 6.2500e-05 - 14s/epoch - 438ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1635 - accuracy: 0.9378 - val_loss: 0.1470 - val_accuracy: 0.9368 - lr: 6.2500e-05 - 14s/epoch - 438ms/step
# Epoch 60/100
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 60: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1843 - accuracy: 0.9250 - val_loss: 0.1528 - val_accuracy: 0.9308 - lr: 6.2500e-05 - 14s/epoch - 441ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1652 - accuracy: 0.9311 - val_loss: 0.1613 - val_accuracy: 0.9229 - lr: 3.1250e-05 - 14s/epoch - 445ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1706 - accuracy: 0.9311 - val_loss: 0.1577 - val_accuracy: 0.9229 - lr: 3.1250e-05 - 14s/epoch - 445ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1687 - accuracy: 0.9327 - val_loss: 0.1554 - val_accuracy: 0.9249 - lr: 3.1250e-05 - 14s/epoch - 446ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1788 - accuracy: 0.9281 - val_loss: 0.1521 - val_accuracy: 0.9269 - lr: 3.1250e-05 - 14s/epoch - 449ms/step
# Epoch 65/100
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 65: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1714 - accuracy: 0.9311 - val_loss: 0.1545 - val_accuracy: 0.9249 - lr: 3.1250e-05 - 14s/epoch - 449ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1809 - accuracy: 0.9260 - val_loss: 0.1538 - val_accuracy: 0.9269 - lr: 1.5625e-05 - 14s/epoch - 446ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1815 - accuracy: 0.9304 - val_loss: 0.1522 - val_accuracy: 0.9308 - lr: 1.5625e-05 - 14s/epoch - 450ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1652 - accuracy: 0.9332 - val_loss: 0.1544 - val_accuracy: 0.9249 - lr: 1.5625e-05 - 14s/epoch - 455ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1776 - accuracy: 0.9291 - val_loss: 0.1590 - val_accuracy: 0.9249 - lr: 1.5625e-05 - 14s/epoch - 446ms/step
# Epoch 70/100
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 70: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1692 - accuracy: 0.9327 - val_loss: 0.1589 - val_accuracy: 0.9249 - lr: 1.5625e-05 - 14s/epoch - 445ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1795 - accuracy: 0.9250 - val_loss: 0.1589 - val_accuracy: 0.9249 - lr: 7.8125e-06 - 14s/epoch - 443ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1959 - accuracy: 0.9240 - val_loss: 0.1571 - val_accuracy: 0.9249 - lr: 7.8125e-06 - 14s/epoch - 452ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1742 - accuracy: 0.9286 - val_loss: 0.1570 - val_accuracy: 0.9249 - lr: 7.8125e-06 - 14s/epoch - 449ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1850 - accuracy: 0.9281 - val_loss: 0.1585 - val_accuracy: 0.9249 - lr: 7.8125e-06 - 14s/epoch - 446ms/step
# Epoch 75/100
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 75: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1835 - accuracy: 0.9194 - val_loss: 0.1582 - val_accuracy: 0.9249 - lr: 7.8125e-06 - 14s/epoch - 451ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1692 - accuracy: 0.9362 - val_loss: 0.1564 - val_accuracy: 0.9249 - lr: 3.9063e-06 - 14s/epoch - 453ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1825 - accuracy: 0.9250 - val_loss: 0.1556 - val_accuracy: 0.9249 - lr: 3.9063e-06 - 14s/epoch - 446ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1712 - accuracy: 0.9327 - val_loss: 0.1559 - val_accuracy: 0.9249 - lr: 3.9063e-06 - 14s/epoch - 444ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1781 - accuracy: 0.9250 - val_loss: 0.1556 - val_accuracy: 0.9249 - lr: 3.9063e-06 - 14s/epoch - 454ms/step
# Epoch 80/100
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 80: val_loss did not improve from 0.14224
# 31/31 - 17s - loss: 0.1723 - accuracy: 0.9265 - val_loss: 0.1552 - val_accuracy: 0.9249 - lr: 3.9063e-06 - 17s/epoch - 555ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1880 - accuracy: 0.9214 - val_loss: 0.1541 - val_accuracy: 0.9249 - lr: 1.9531e-06 - 14s/epoch - 445ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1909 - accuracy: 0.9250 - val_loss: 0.1535 - val_accuracy: 0.9269 - lr: 1.9531e-06 - 14s/epoch - 440ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1775 - accuracy: 0.9316 - val_loss: 0.1537 - val_accuracy: 0.9269 - lr: 1.9531e-06 - 14s/epoch - 439ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1992 - accuracy: 0.9184 - val_loss: 0.1530 - val_accuracy: 0.9269 - lr: 1.9531e-06 - 14s/epoch - 441ms/step
# Epoch 85/100
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 85: val_loss did not improve from 0.14224
# 31/31 - 15s - loss: 0.1777 - accuracy: 0.9342 - val_loss: 0.1544 - val_accuracy: 0.9269 - lr: 1.9531e-06 - 15s/epoch - 482ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1500 - accuracy: 0.9398 - val_loss: 0.1543 - val_accuracy: 0.9249 - lr: 9.7656e-07 - 14s/epoch - 449ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1603 - accuracy: 0.9378 - val_loss: 0.1536 - val_accuracy: 0.9249 - lr: 9.7656e-07 - 14s/epoch - 444ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1733 - accuracy: 0.9337 - val_loss: 0.1552 - val_accuracy: 0.9249 - lr: 9.7656e-07 - 14s/epoch - 442ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1674 - accuracy: 0.9235 - val_loss: 0.1543 - val_accuracy: 0.9249 - lr: 9.7656e-07 - 14s/epoch - 447ms/step
# Epoch 90/100
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 90: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1709 - accuracy: 0.9260 - val_loss: 0.1559 - val_accuracy: 0.9249 - lr: 9.7656e-07 - 14s/epoch - 454ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1773 - accuracy: 0.9316 - val_loss: 0.1558 - val_accuracy: 0.9249 - lr: 4.8828e-07 - 14s/epoch - 454ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1935 - accuracy: 0.9219 - val_loss: 0.1556 - val_accuracy: 0.9249 - lr: 4.8828e-07 - 14s/epoch - 445ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1724 - accuracy: 0.9301 - val_loss: 0.1558 - val_accuracy: 0.9249 - lr: 4.8828e-07 - 14s/epoch - 451ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1684 - accuracy: 0.9337 - val_loss: 0.1552 - val_accuracy: 0.9269 - lr: 4.8828e-07 - 14s/epoch - 450ms/step
# Epoch 95/100
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 95: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1683 - accuracy: 0.9301 - val_loss: 0.1558 - val_accuracy: 0.9249 - lr: 4.8828e-07 - 14s/epoch - 452ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1747 - accuracy: 0.9265 - val_loss: 0.1551 - val_accuracy: 0.9249 - lr: 2.4414e-07 - 14s/epoch - 443ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1618 - accuracy: 0.9311 - val_loss: 0.1561 - val_accuracy: 0.9249 - lr: 2.4414e-07 - 14s/epoch - 442ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1711 - accuracy: 0.9276 - val_loss: 0.1566 - val_accuracy: 0.9249 - lr: 2.4414e-07 - 14s/epoch - 445ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1731 - accuracy: 0.9325 - val_loss: 0.1564 - val_accuracy: 0.9249 - lr: 2.4414e-07 - 14s/epoch - 449ms/step
# Epoch 100/100
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 100: val_loss did not improve from 0.14224
# 31/31 - 14s - loss: 0.1816 - accuracy: 0.9270 - val_loss: 0.1568 - val_accuracy: 0.9249 - lr: 2.4414e-07 - 14s/epoch - 451ms/step

# %% [markdown]
# ## Final Loss and Accuracy

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 1s 72ms/step - loss: 0.1568 - accuracy: 0.9249
# Final Loss: 0.15679039061069489, Final Accuracy: 0.9249011874198914

# %% [markdown]
# ## Confusion Matrix

# %%
Y_pred = model.predict(X_val)
Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)
cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       261
#            1       0.96      0.88      0.92       245
#
#     accuracy                           0.92       506
#    macro avg       0.93      0.92      0.92       506
# weighted avg       0.93      0.92      0.92       506

# %% [markdown]
# ## Accuracy and Loss Curve

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Prediction from Image

# %%
# Read Image
img = image.load_img('/content/drive/MyDrive/03_March/Btech_cv19/ConStr/COVID/a.png', grayscale=False, target_size=(64, 64))
show_img = image.load_img('/content/drive/MyDrive/03_March/Btech_cv19/ConStr/COVID/1.png', grayscale=False, target_size=(200, 200))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-17c8ec7994ec> in <module>()
#       1 # Read Image
# ----> 2 img = image.load_img('/content/drive/MyDrive/03_March/Btech_cv19/ConStr/COVID/a.png', grayscale=False, target_size=(64, 64))
#       3 show_img = image.load_img('/content/drive/MyDrive/03_March/Btech_cv19/ConStr/COVID/1.png', grayscale=False, target_size=(200, 200))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'load_img'

# %%
# Preprocess image for prediction 
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

# %%
# Predict Image
custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
